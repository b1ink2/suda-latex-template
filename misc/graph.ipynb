# %%
import matplotlib.pyplot as plt

# 示例数据（替换为你自己的数据）
epochs = list(range(1, 11))  # 假设训练了20个epoch
# test_loss = [0.325, 0.185, 0.126, 0.132, 0.121, 0.119, 0.137, 0.151, 0.156, 0.171]
# test_acc =  [0.891, 0.943, 0.964, 0.960, 0.965, 0.967, 0.963, 0.961, 0.960, 0.961]
# max
# test_loss = [0.418, 0.235, 0.160, 0.115, 0.090, 0.096, 0.086, 0.101, 0.097, 0.077]
# test_acc = [0.865, 0.933, 0.953, 0.967, 0.973, 0.972, 0.975, 0.972, 0.973, 0.976]
# dft
# test_loss = [0.376, 0.240, 0.128, 0.131, 0.113, 0.091, 0.096, 0.076, 0.072, 0.083]
# test_acc = [0.869, 0.936, 0.965, 0.961, 0.970, 0.976, 0.974, 0.976, 0.980, 0.978]
# conv
# test_loss = [0.356, 0.187, 0.130, 0.105, 0.094, 0.089, 0.090, 0.112, 0.101, 0.077]
# test_acc = [0.892, 0.947, 0.963, 0.965, 0.973, 0.972, 0.974, 0.970, 0.973, 0.978]
# standard
test_loss = [0.408, 0.200, 0.126, 0.094, 0.089, 0.080, 0.078, 0.090, 0.073, 0.081]
test_acc = [0.864, 0.940, 0.960, 0.969, 0.972, 0.976, 0.976, 0.975, 0.979, 0.978]
plt.figure(figsize=(6, 5))

# 创建主坐标轴（左侧Y轴）
ax1 = plt.gca()
ax1.plot(epochs, test_loss, 'r-', label='Test Loss', linewidth=2)
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='r')
ax1.tick_params(axis='y', labelcolor='r')
ax1.grid(True, linestyle='--', alpha=0.3)

# 创建次坐标轴（右侧Y轴）
ax2 = ax1.twinx()
ax2.plot(epochs, test_acc, 'b-', label='Test Accuracy', linewidth=2)
ax2.set_ylabel('Accuracy ', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 设置标题和图例
plt.title('VNAT 10 Epochs Test Metrics (standard)')
fig = plt.gcf()
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

# 保存并显示
plt.tight_layout()
plt.savefig('VNATstandard.png', dpi=300)
